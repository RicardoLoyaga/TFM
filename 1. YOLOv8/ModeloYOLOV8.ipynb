# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 27.5 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# Carga un modelo pre-entrenado
model = YOLO('yolov8n.pt')

# Entrena el modelo con tu dataset
results = model.train(data='/content/drive/MyDrive/plaga_cacao.yaml', epochs=100, imgsz=640)
# Out:
# Ultralytics 8.3.197 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
